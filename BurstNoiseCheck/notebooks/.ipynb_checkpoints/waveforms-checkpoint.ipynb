# %%
import sys; sys.path.insert(0, '/Users/erezcohen/larlite/UserDev/AnalysisTreesInformation/AnaTreesPackage/notebooks/')
from notebooks_tools import * 
import ROOT , rootpy
from root_numpy import hist2array
from matplotlib.ticker import NullFormatter
# %matplotlib inline
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
U_mb = np.concatenate([np.arange(0,1728,48),np.arange(1728,2400,96)])
U_mb_last = np.concatenate([np.arange(0+47,1728+47,48),np.arange(1728+95,2400+95,96)])

V_mb = np.concatenate([np.arange(2400,3072,96),np.arange(3072,4800,48)])
V_mb_last = np.concatenate([np.arange(2400+95,3072+95,96),np.arange(3072+47,4800+47,48)])

Y_mb = np.arange(4800,8256,96)
Y_mb_last = np.arange(4800+95,8256+95,96)
print len(U_mb),len(U_mb_last),len(V_mb),len(V_mb_last),len(Y_mb),len(Y_mb_last)
# Out:
# 43 43 43 43 36 36

# %% [markdown]
# # run 9778 - burst events

# %%
histograms_file = ROOT.TFile('/Users/erezcohen/Desktop/uBoone/analysis/BurstNoiseCheckEvents/run9778_subrun_1_2_events_8_9_23_32.root')

# %%
event=9
t_min , t_max = 0 , 8200
title = 'event %d wave-forms'%event
title = 'U plane'
fig,ax=plt.subplots(figsize=(12,6))
for wire in np.arange(1105,2200,1):
    h = histograms_file.Get("h_wf_evnt%d_wire%d"%(event , wire))
    histo=hist2array(h)
    plt.plot(np.arange(t_min , t_max,1), histo[t_min:t_max],label='wire %d'%wire)
# set_axes(ax,x_label='time tick',y_label='ADC',fontsize=20)
# ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=20)
ax.grid('--',alpha=0.75)
ax.set_title(title,y=1.02,fontsize=25)

# %%
event , t_min , t_max = 8 , 4700 , 5100 # event 8 plane U
# event , t_min , t_max = 9 , 600 , 1200 # event 9 plane U

fig = plt.figure(figsize=(25,20))
title = 'around the mother-boards'
mb_set , mb_set_last = U_mb , U_mb_last
N = int(np.sqrt(len(mb_set)))+1
print N
for i in range(1,np.min([len(mb_set)-1,N*N])):
    wire , wire_last = mb_set[i] , mb_set_last[i-1]
    ax=fig.add_subplot(7,6,i+1)
    h_first=hist2array(histograms_file.Get("h_wf_evnt%d_wire%d"%(event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h_first[t_min:t_max])

    h_last =hist2array(histograms_file.Get("h_wf_evnt%d_wire%d"%(event , wire_last)))
    plt.plot(np.arange(t_min , t_max,1), h_last[t_min:t_max])


    ax.legend(loc='best',fontsize=20)
    ax.set_title('%d/%d'%(wire_last,wire),y=0.86,fontsize=15)
    ax.grid('--',alpha=0.75)
    ax.xaxis.set_major_formatter( NullFormatter() )
    ax.yaxis.set_major_formatter( NullFormatter() )
# Out:
# 7

# %% [markdown]
# # burst runs with 0kV

# %%
histograms_file = ROOT.TFile('/Users/erezcohen/Desktop/uBoone/analysis/BurstNoiseCheckEvents/burst_events_study_output.root')

# %%
run , subrun , event = 9888 , 106 , 5329
wire , t_min , t_max = 1 , 3750 , 3800
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
# title = 'U plane'
fig,ax=plt.subplots(figsize=(12,6))
for wire in np.arange(0,2400,1):
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
# set_axes(ax,x_label='time tick',y_label='ADC',fontsize=20)
# ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=15,ncol=2)
ax.xaxis.set_major_formatter( NullFormatter() )
ax.yaxis.set_major_formatter( NullFormatter() )
ax.grid('--',alpha=0.75)
# ax.set_title(title,y=1.02,fontsize=25)

# %%
def plot_wf_near_motherboards(mb_set=U_mb , mb_set_last=U_mb_last, 
                              run=9888, subrun=106 , event=5329 ,
                              t_min=3600 , t_max=4100):

    fig = plt.figure(figsize=(25,20))
    N = int(np.sqrt(len(mb_set)))+1

    for i in range(1,len(mb_set)-1):
        wire , wire_last = mb_set[i] , mb_set_last[i-1]
        ax=fig.add_subplot(len(mb_set)/6,6,i+1)

        h_last=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire_last)))
        plt.plot(np.arange(t_min , t_max,1), h_last[t_min:t_max] , color='blue')

        h_first=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
        plt.plot(np.arange(t_min , t_max,1), h_first[t_min:t_max] , color='green')


        ax.legend(loc='best',fontsize=20)
        y_min,y_max=ax.get_ylim()
        plt.text(t_min+0.45*(t_max-t_min), y_min+0.9*(y_max-y_min), "%d"%wire_last, fontsize=15, color='blue', ha ='right')
        plt.text(t_min+0.5*(t_max-t_min), y_min+0.9*(y_max-y_min), "/", fontsize=15, color='black', ha ='center')
        plt.text(t_min+0.55*(t_max-t_min), y_min+0.9*(y_max-y_min), "%d"%wire, fontsize=15, color='green', ha ='left')

        ax.grid('--',alpha=0.75)
        ax.xaxis.set_major_formatter( NullFormatter() )
        ax.yaxis.set_major_formatter( NullFormatter() )

# %%
plot_wf_near_motherboards(mb_set=U_mb , mb_set_last=U_mb_last, 
                              run=9778, subrun=0 , event=8 ,
                              t_min=4500 , t_max=5200)

# %%
plot_wf_near_motherboards(mb_set=U_mb , mb_set_last=U_mb_last, 
                              run=9888, subrun=106 , event=5329 ,
                              t_min=3700 , t_max=3900)

# %%
plot_wf_near_motherboards(mb_set=U_mb , mb_set_last=U_mb_last, 
                              run=9888, subrun=31 , event=1588 ,
                              t_min=6300 , t_max=6400)

# %%
plot_wf_near_motherboards(mb_set=U_mb , mb_set_last=U_mb_last, 
                              run=9888, subrun=31 , event=1588 ,
                              t_min=6300 , t_max=6400)

# %% [markdown]
# # runs with 7kV, burst events

# %%
histograms_file = ROOT.TFile('/Users/erezcohen/Desktop/uBoone/analysis/BurstNoiseCheckEvents/burst_events_7kV.root')

# %%
run , subrun , event = 9975 , 1 , 93
wire , t_min , t_max = 1 , 1 , 9000
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig,ax=plt.subplots(figsize=(12,6))
for wire in np.arange(0,2300,50):
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
set_axes(ax,x_label='time tick',y_label='ADC',fontsize=20)
ax.grid('--',alpha=0.75)
ax.set_title(title,y=1.02,fontsize=25)

# %%
run , subrun , event = 9975 , 1 , 93
wire , t_min , t_max = 1 , 2100 , 6000
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig,ax=plt.subplots(figsize=(12,6))
for wire in np.array([0,672/2,672,2400-672,2400-672/2,2400]):
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
set_axes(ax,x_label='time tick',y_label='ADC',fontsize=20)
ax.grid('--',alpha=0.75)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=20,ncol=1)

# ax.set_title(title,y=1.02,fontsize=25)

# %%
run , subrun , event = 9975 , 1 , 93
wire , t_min , t_max = 1 , 2100 , 5000
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig=plt.figure(figsize=(15,10))
for i,wire in enumerate([0,2400,672/2,2400-672/2,672,2400-672]):
    ax=fig.add_subplot(3,2,i+1)
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max])
    plt.title('wire %d'%wire,y=0.8,fontsize=25)
    if (i<4):
        ax.xaxis.set_major_formatter( NullFormatter() )
        x_label=''
    ax.yaxis.set_major_formatter( NullFormatter() )        
    set_axes(ax,x_label=x_label,y_label='',fontsize=20)
    ax.grid('--',alpha=0.75)
plt.subplots_adjust(hspace=0.01,wspace=0.2)

# %%
run , subrun , event = 9975 , 1 , 93
wire , t_min , t_max = 1 , 2100 , 5000
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig,ax=plt.subplots(figsize=(12,6))
for wire in np.array([2401,2401+672/2,2401+672,4800-672,4800-672/2,4800]):
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
set_axes(ax,x_label='time tick',y_label='ADC',fontsize=20)
ax.grid('--',alpha=0.75)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=20,ncol=1)

# %%
run , subrun , event = 9975 , 1 , 93
wire , t_min , t_max = 1 , 2100 , 5000
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig=plt.figure(figsize=(15,10))
for i,wire in enumerate([2401,2401+672/2,2401+672,4800-672,4800-672/2,4800]):
    ax=fig.add_subplot(3,2,i+1)
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max])
    plt.title('wire %d'%wire,y=0.8,fontsize=25)
    if (i<4):
        ax.xaxis.set_major_formatter( NullFormatter() )
        x_label=''
    ax.yaxis.set_major_formatter( NullFormatter() )        
    set_axes(ax,x_label=x_label,y_label='',fontsize=20)
    ax.grid('--',alpha=0.75)
plt.subplots_adjust(hspace=0.01,wspace=0.2)

# %%
run , subrun , event = 9975 , 1 , 93
wire , t_min , t_max = 1 , 2620 , 2800
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig=plt.figure(figsize=(20,10))
ax=fig.add_subplot(1,1,1)

for i,wire in enumerate([6336,6337,6338,6339]):#,6337,6338,6339]):#np.arange(4801,8256,96*4)):
#     ax=fig.add_subplot(1,1,i+1)
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
    # plt.title('w-%d'%wire,y=0.8,fontsize=15)
#     if (i<4):
#         ax.xaxis.set_major_formatter( NullFormatter() )
x_label='time [$\\mu sec$]'
#     ax.yaxis.set_major_formatter( NullFormatter() )
#     ax.xaxis.set_major_formatter( NullFormatter() )
newticks=ax.get_xticklabels()
labels = np.array(ax.get_xticks().tolist())
newticks = 0.0005*labels
ax.set_ylim(-100,2500)
ax.set_xticklabels(['%.3f'%newtick for newtick in newticks])
set_axes(ax,x_label=x_label,y_label='ADC',fontsize=20)
ax.grid('--',alpha=0.75)
ax.legend(loc='best',fontsize=25)
plt.subplots_adjust(hspace=0.2,wspace=0.2)

# %% [markdown]
# # burst run from Dec-2015

# %%
histograms_file = ROOT.TFile('/Users/erezcohen/Desktop/uBoone/analysis/BurstNoiseCheckEvents/Dec15_burstevent.root')

# %%
run , subrun , event = 4172 , 417 , 20855
wire , t_min , t_max = 1 , 1 , 9000
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig,ax=plt.subplots(figsize=(12,6))
for wire in np.arange(0,2300,50):
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
set_axes(ax,x_label='time tick',y_label='ADC',fontsize=20)
ax.grid('--',alpha=0.75)
ax.set_title(title,y=1.02,fontsize=25)

# %%
run , subrun , event = 4172 , 417 , 20855
t_min , t_max = 2800 , 3000
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig,ax=plt.subplots(figsize=(12,6))
for wire in np.array([0,672/2,672,2400-672,2400-672/2,2400]): #[2401,2401+672/2,2401+672,4800-672,4800-672/2,4800]
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
set_axes(ax,x_label='time tick',y_label='ADC',fontsize=20)
ax.grid('--',alpha=0.75)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=20,ncol=1)

# %%
run , subrun , event = 4172 , 417 , 20855
wire , t_min , t_max = 1 , 2800 , 3000
fig=plt.figure(figsize=(15,10))
for i,wire in enumerate([0,2400,672/2,2400-672/2,672,2400-672]):#[2401,2401+672/2,2401+672,4800-672,4800-672/2,4800]
    ax=fig.add_subplot(3,2,i+1)
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max])
    plt.title('wire %d'%wire,y=0.85,fontsize=25)
    if (i<4):
        ax.xaxis.set_major_formatter( NullFormatter() )
        x_label=''
    ax.yaxis.set_major_formatter( NullFormatter() )        
    set_axes(ax,x_label=x_label,y_label='',fontsize=20)
    ax.grid('--',alpha=0.75)
plt.subplots_adjust(hspace=0.01,wspace=0.2)

# %%
run , subrun , event = 4172 , 417 , 20855
wire , t_min , t_max = 1 , 2800 , 3000
fig=plt.figure(figsize=(16,12))

for i,wire in enumerate(np.arange(4801,8256,96)):#,6337,6338,6339]):#np.arange(4801,8256,96*4)):
    ax=fig.add_subplot(6,6,i+1)
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
    plt.title('w-%d'%wire,y=0.8,fontsize=15)
    if (i<4):
        ax.xaxis.set_major_formatter( NullFormatter() )
    x_label=''#time [$\\mu sec$]'
    ax.yaxis.set_major_formatter( NullFormatter() )
    ax.xaxis.set_major_formatter( NullFormatter() )
# ax.set_ylim(-100,2500)
    set_axes(ax,x_label=x_label,y_label='',fontsize=20)
    ax.grid('--',alpha=0.75)
#     ax.legend(loc='best',fontsize=25)
    plt.subplots_adjust(hspace=0.,wspace=0.)

# %% [markdown]
# # burst and non-burst events in the 35kV runs with the wire bias off and pick off point at 0V

# %%
histograms_file = ROOT.TFile('/Users/erezcohen/Desktop/uBoone/analysis/BurstNoiseCheckEvents/zigzag_noise_run10039.root')

# %%
run , subrun , event = 10039 , 0 , 15
t_min , t_max = 8000 , 9594
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig,ax=plt.subplots(figsize=(12,6))
for wire in np.arange(0,2300,200):
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
set_axes(ax,x_label='time tick',y_label='ADC',fontsize=20)
ax.grid('--',alpha=0.75)
ax.set_title(title,y=1.02,fontsize=25)

# %%
run , subrun , event = 10039 , 0 , 15
t_min , t_max = 8200 , 8900#9594
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig,ax=plt.subplots(figsize=(12,6))
# for wire in np.array([0,672/2,672,2400-672,2400-672/2,2400]): 
for wire in np.array([2401,2401+672/2,2401+672,4800-672,4800-672/2,4800]): 

    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
set_axes(ax,x_label='time tick',y_label='ADC',fontsize=20)
ax.grid('--',alpha=0.75)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=20,ncol=1)

# %%
run , subrun , event = 10039 , 0 , 15
t_min , t_max = 8200 , 8550

fig=plt.figure(figsize=(15,10))
# for i,wire in enumerate([0,2400,672/2,2400-672/2,672,2400-672]):
for i,wire in enumerate([2401,2401+672/2,2401+672,4800-672,4800-672/2,4800]):

    ax=fig.add_subplot(3,2,i+1)
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max])
    plt.title('wire %d'%wire,y=0.85,fontsize=25)
    if (i<4):
        ax.xaxis.set_major_formatter( NullFormatter() )
        x_label=''
    ax.yaxis.set_major_formatter( NullFormatter() )        
    set_axes(ax,x_label=x_label,y_label='',fontsize=20)
    ax.grid('--',alpha=0.75)
    plt.xticks(np.arange(t_min,t_max,150))
plt.subplots_adjust(hspace=0.,wspace=0.1)

# %%
run , subrun , event = 10039 , 1 , 59
t_min , t_max = 8200 , 8900#9594
title = 'r-%d/s-%d/e-%d wave-forms'%(run , subrun , event)
fig,ax=plt.subplots(figsize=(12,6))
# for wire in np.array([0,672/2,672,2400-672,2400-672/2,2400]): 
for wire in np.array([2401,2401+672/2,2401+672,4800-672,4800-672/2,4800]): 

    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max],label='wire %d'%wire)
set_axes(ax,x_label='time tick',y_label='ADC',fontsize=20)
ax.grid('--',alpha=0.75)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize=20,ncol=1)
run , subrun , event = 10039 , 0 , 15
t_min , t_max = 8200 , 8550

fig=plt.figure(figsize=(15,10))
# for i,wire in enumerate([0,2400,672/2,2400-672/2,672,2400-672]):
for i,wire in enumerate([2401,2401+672/2,2401+672,4800-672,4800-672/2,4800]):

    ax=fig.add_subplot(3,2,i+1)
    h=hist2array(histograms_file.Get("h_wf_r%d_s%d_e%d_wire%d"%(run , subrun , event , wire)))
    plt.plot(np.arange(t_min , t_max,1), h[t_min:t_max])
    plt.title('wire %d'%wire,y=0.85,fontsize=25)
    if (i<4):
        ax.xaxis.set_major_formatter( NullFormatter() )
        x_label=''
    ax.yaxis.set_major_formatter( NullFormatter() )        
    set_axes(ax,x_label=x_label,y_label='',fontsize=20)
    ax.grid('--',alpha=0.75)
    plt.xticks(np.arange(t_min,t_max,150))
plt.subplots_adjust(hspace=0.,wspace=0.1)
